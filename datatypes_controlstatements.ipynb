# %%
h = 10
s = str(h)
print(type(h))
print(type(s))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# There are datatypes available in Python
# Standard Datatypes
#1. Numeric
#2. Dictionary
#3. Boolean
#4. Set
#5. Sequance

# Numeric
#int float complex

# Sequance
# string list tuple
h = 10
g = 10.1
i = 10.1j

print(type(h))
print(type(g))
print(type(i))

h2 = 10
h3 = 5
h1 = h2<h3
print(h1)
print(type(h1))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# False
# <class 'bool'>

# %%
# Control Statements and Looping Statements
# Before Control Statements.... we need to know .. Logical Conditions
# 1. Equals: a == b
# 2. Not Equals: a != b
# 3. Less than: a < b
# 4. Less than or equal to: a <= b
# 5. Greater than: a > b
# 6. Greater than or equal to: a >= b

# if... else
# while Loop
# for Loop

# %%
# List 

# List Syntax is: List1 = [ ] 

# Built in Data Type 

# Basic data structure in Python

# List is a collection......   which is ordered and changeable.

# can be defined as a collection of values or items of different types

l = ["CSE","B1",1,2,"Hello",2.5]
#print(l)
#print(type(l))

# Allows duplicate members.

l1 = [1,2,3,4,4,2,3,1]
#print(l1)

# lists are mutable type its mean we can modify its element after it created

l[0]=1
#print(l)

# The element of the list can access by index.  0,1,2,3,4
#print(l1[2])

# Allows negative indexing
#print(l1[-2])

# Reverse the data sequance

l4 = [1,2,3,4,5,6,7,8]

#print("l4",l4)
l3 = l4

#print("l3",l3)

l3.reverse()
#print("reverse l3:",l3)
#print("l4",l4)
#print(l4)
#print(l3)

del l4
#print(l4)

# sort the sequance

l4 = [2,1,4,3,5,8,6,7]
#print(l4)

l4.sort()
#print(l4)
del l4
del l3

# Merge the sequance 
l3 = [1,2,3]
l4 = [4,5,6]
l5 = l3 + l4

print(l3)
print(l4)
print(l5)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %%
#Assignment is 

# you need to create the list's L1 & L2 

# input for L1 & L2 need to be taken from the user ( input: numeric values)

# print L1 & L2

# L2 need to reversed

# sort funtion need to applied on L1

# First two items need to be taken from L2 and these items need to be added with L1

# %%
#Tuple

# is also a collection of ordered objects

# In someways a tuple is similar to a list in terms of indexing....

# nested objects and repetition but a tuple is immutable unlike lists which are mutable

# can be defined as a collection of values or items of different types

# Allows duplicate members.

# The element of the tuple can access by index.

# Allows negative indexing

# Syntax----  tup1 = (); 

# immutable is the point of focus

# Sorting is not possible with Tuple - "Tuple is Immutable"


Tup1 = ("a1",1,2,"python",2.5)

print(Tup1)

Tup2 =(1)

print(Tup2)

print(type(Tup1))

#print(type(Tup2))

#Tup3 = Tup1 + Tup2

#print(Tup3)  TypeError: can only concatenate tuple (not "int") to tuple

Tup4 = (5,6)

Tup3 = Tup1 + Tup4

print(Tup3)

print(type(Tup4))

Tup4[2] = 4    # Tupe is immutable : TypeError: 'tuple' object does not support item assignment

print(Tup4)  

Tup5 =(7,8,9,10)


# List is Mutable 

L9 = [1,2,3,4,4]

#print(L9)

#print(type(L9))

L9[2] = 7

#print(L9)

# Tup4 = Tup4 + L9  TypeError: can only concatenate tuple (not "list") to tuple


Tup4 = Tup4 + Tup5     # Merge two data sequences 

#print(Tup4) 

#print(Tup4[-1])    # Negative Indexing

#print(Tup4[1:])

#print(Tup4[1:4])   # Display the data specific sequance 

Tup7 = (1,4,2,7,3,9,8)

# Tup7.sort()    Mutable objects can change their values, while immutable objects can not be altered

# print(Tup7)

# Tup7.reverse()  Mutable objects can change their values, while immutable objects can not be altered
# Out:
# ('a1', 1, 2, 'python', 2.5)
# 1
# <class 'tuple'>
# ('a1', 1, 2, 'python', 2.5, 5, 6)
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 48
#      44 print(Tup3)
#      46 print(type(Tup4))
# ---> 48 Tup4[2] = 4    # Tupe is immutable : TypeError: 'tuple' object does not support item assignment
#      50 print(Tup4)
#      52 Tup5 =(7,8,9,10)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Set

# is the collection of the unordered items.

# Each element in the set must be unique, immutable

# sets remove the duplicate elements

# Sets are mutable which means we can modify it after its creation

# no index attached to the elements of the set

# can be created by enclosing the comma-separated immutable items with the curly braces { }

# also provides the set( ) method, which can be used to create the set by the passed sequence.



set1 = {"mon","tue","wed","thu","fri","sat","sun"}   # Method 1

set2 = (["mon","tue","wed","thu","fri","sat","sun"]) # Method 2

print(set1)

print(set2)

print(type(set1))

print(type(set2))

set3 = {1,2,3,4,5,6,6,7,8,9,9}

#print(set3)    # will return unique elements

set4 = {6,7,8,9}

set5 = {2,3,4,6,7}

set6 = set4.union(set5)  # Join two sets

#print(set6)

#set6.add(11)

#print(set6)

set6.update([12,13,14])

#print(set6)


List10 = []

tuple10 = ()

set7 = {}

#print(type(List10))

#print(type(tuple10))

#print(type(set7))
